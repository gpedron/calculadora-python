# %% [markdown]
# # Calculadora inteligente
#
#
#
# 1.   Utilize o comando 'input' para receber ao menos 2 números de entrada do usuário;
#
# 2. Converta os valores recebidos pelo usuário para número inteiro (int) ou ponto flutuante (float);
#
# 3. Implemente ao menos 4 operações matemáticas em seu código;
#
# 4. Adicione um laço de repetição ou uma condicional. Por exemplo: você pode permitir que o usuário escolha qual operação realizar ou criar um loop que permita ao usuário realizar várias operações consecutivas;
#
# 5. Utilize o comando 'print' para exibir o resultado da operação matemática.

# %%
# Identificar o usuário e Definir qual a operação matemática

nome = input("Escreva seu nome: ")

while True: # while para definir as operações e encerrar a calculadora( irá repetir até a escolha número 5)

    print("\n") #\n é um espaço entre as linhas
    print("Olá " + nome, "Antes de iniciarmos, escolha uma das operações matemáticas:")
    print("1 - Soma")
    print("2 - Subtração")
    print("3 - Multiplicação")
    print("4 - Divisão")
    print("5 - Sair")
    print("\n") #\n é um espaço entre as linhas

    opção = int(input("Escolha uma opção: "))

    if opção == 5:
        print("Calculadora encerrada.")
        break

    num1 = float(input("Digite o primeiro número: "))
    num2 = float(input("Digite o segundo número: "))

    if(opção == 1):
        print("Soma: ", num1 + num2)

    if(opção == 2):
        print("Subtração: ", num1 - num2)

    if(opção == 3):
        print("Multiplicação: ", num1 * num2)

    if(opção == 4):
      if(num2 == 0):
        print("Não é possível dividir por zero.")
      else:
        print("Divisão:", num1 / num2)

    else:
        print("Opção inválida. Por favor, escolha uma opção válida.")
# Out:
# Escreva seu nome: Gabriel
#
#
# Olá Gabriel Antes de iniciarmos, escolha uma das operações matemáticas:
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# 5 - Sair
#
#
# Escolha uma opção: 4
# Digite o primeiro número: 1
# Digite o segundo número: 3
# Divisão: 0.3333333333333333
#
#
# Olá Gabriel Antes de iniciarmos, escolha uma das operações matemáticas:
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# 5 - Sair
#
#
# Escolha uma opção: 2
# Digite o primeiro número: 4
# Digite o segundo número: 3
# Subtração:  1.0
# Opção inválida. Por favor, escolha uma opção válida.
#
#
# Olá Gabriel Antes de iniciarmos, escolha uma das operações matemáticas:
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# 5 - Sair
#
#
# Escolha uma opção: 5
# Calculadora encerrada.
